# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# # API Connection Parameters

# %%
api_key = 'afd16a138ce043b0b1e895c39b291dc9'
base_url = 'https://api.sportsdata.io/v3/cbb/scores/json/TeamSeasonStats'

# %% [markdown]
# # Make Requests Based on a Given Year

# %%
season = '2022'
url = f'{base_url}/{season}?key={api_key}'

response = requests.get(url=url)
season_stats = response.json()

# %%
season = '2022POST'
url = f'{base_url}/{season}?key={api_key}'

response = requests.get(url=url)
season_stats = season_stats + response.json()

# %%
season_stats
# Out:
# [{'StatID': 895395,
#   'TeamID': 1203,
#   'SeasonType': 1,
#   'Season': 2022,
#   'Name': 'Ohio Christian Trailblazers',
#   'Team': '',
#   'Wins': 0,
#   'Losses': 1,
#   'ConferenceWins': 0,
#   'ConferenceLosses': 0,
#   'GlobalTeamID': 60001203,
#   'Possessions': 138.8,
#   'Updated': '2022-05-31T22:12:53',
#   'Games': 1,
#   'FantasyPoints': 137.7,
#   'Minutes': 400,
#   'FieldGoalsMade': 35,
#   'FieldGoalsAttempted': 137,
#   'FieldGoalsPercentage': 43.8,
#   'EffectiveFieldGoalsPercentage': 48.1,
#   'TwoPointersMade': 28,
#   'TwoPointersAttempted': 78,
#   'TwoPointersPercentage': 61.7,
#   'ThreePointersMade': 12,
#   'ThreePointersAttempted': 59,
#   'ThreePointersPercentage': 20.4,
#   'FreeThrowsMade': 15,
#   'FreeThrowsAttempted': 12,
#   'FreeThrowsPercentage': 123.7,
#   'OffensiveRebounds': 24,
#   'DefensiveRebounds': 19,
#   'Rebounds': 43,
#   'OffensiveReboundsPercentage': None,
#   'DefensiveReboundsPercentage': None,
# ...
