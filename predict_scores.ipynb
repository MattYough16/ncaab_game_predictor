# %%
import pandas as pd
import requests
import json
import http.client
import time
import numpy as np
from datetime import date, datetime
import joblib
from sportsipy.ncaab.teams import Teams
from sportsipy.ncaab.schedule import Schedule
from sportsipy.ncaab.boxscore import Boxscores

# %% [markdown]
# # Get the Game Schedule for the Current Day

# %%
date = date.today()
year = date.year

teams = Teams(year=year)

# %% [markdown]
# # Loop through teams and get current stats

# %%
# Out:
# Abilene Christian (ABILENE-CHRISTIAN/MEN)
# Air Force (AIR-FORCE/MEN)
# Akron (AKRON/MEN)
# Alabama (ALABAMA/MEN)
# Alabama A&M (ALABAMA-AM/MEN)
# Alabama State (ALABAMA-STATE/MEN)
# Albany (NY) (ALBANY-NY/MEN)
# Alcorn State (ALCORN-STATE/MEN)
# American (AMERICAN/MEN)
# Appalachian State (APPALACHIAN-STATE/MEN)
# Arizona (ARIZONA/MEN)
# Arizona State (ARIZONA-STATE/MEN)
# Arkansas (ARKANSAS/MEN)
# Arkansas State (ARKANSAS-STATE/MEN)
# Arkansas-Pine Bluff (ARKANSAS-PINE-BLUFF/MEN)
# Army (ARMY/MEN)
# Auburn (AUBURN/MEN)
# Austin Peay (AUSTIN-PEAY/MEN)
# Ball State (BALL-STATE/MEN)
# Baylor (BAYLOR/MEN)
# Bellarmine (BELLARMINE/MEN)
# Belmont (BELMONT/MEN)
# Bethune-Cookman (BETHUNE-COOKMAN/MEN)
# Binghamton (BINGHAMTON/MEN)
# Boise State (BOISE-STATE/MEN)
# Boston College (BOSTON-COLLEGE/MEN)
# Boston University (BOSTON-UNIVERSITY/MEN)
# Bowling Green State (BOWLING-GREEN-STATE/MEN)
# Bradley (BRADLEY/MEN)
# Brigham Young (BRIGHAM-YOUNG/MEN)
# Brown (BROWN/MEN)
# Bryant (BRYANT/MEN)
# Bucknell (BUCKNELL/MEN)
# Buffalo (BUFFALO/MEN)
# Butler (BUTLER/MEN)
# Cal Poly (CAL-POLY/MEN)
# Cal State Bakersfield (CAL-STATE-BAKERSFIELD/MEN)
# Cal State Fullerton (CAL-STATE-FULLERTON/MEN)
# Cal State Northridge (CAL-STATE-NORTHRIDGE/MEN)
# California (CALIFORNIA/MEN)
# California Baptist (CALIFORNIA-BAPTIST/MEN)
# Campbell (CAMPBELL/MEN)
# Canisius (CANISIUS/MEN)
# Central Arkansas (CENTRAL-ARKANSAS/MEN)
# Central Connecticut State (CENTRAL-CONNECTICUT-STATE/MEN)
# Central Florida (CENTRAL-FLORIDA/MEN)
# Central Michigan (CENTRAL-MICHIGAN/MEN)
# Charleston Southern (CHARLESTON-SOUTHERN/MEN)
# Charlotte (CHARLOTTE/MEN)
# Chattanooga (CHATTANOOGA/MEN)
# Chicago State (CHICAGO-STATE/MEN)
# Cincinnati (CINCINNATI/MEN)
# Clemson (CLEMSON/MEN)
# Cleveland State (CLEVELAND-STATE/MEN)
# Coastal Carolina (COASTAL-CAROLINA/MEN)
# Colgate (COLGATE/MEN)
# College of Charleston (COLLEGE-OF-CHARLESTON/MEN)
# Colorado (COLORADO/MEN)
# Colorado State (COLORADO-STATE/MEN)
# Columbia (COLUMBIA/MEN)
# Connecticut (CONNECTICUT/MEN)
# Coppin State (COPPIN-STATE/MEN)
# Cornell (CORNELL/MEN)
# Creighton (CREIGHTON/MEN)
# Dartmouth (DARTMOUTH/MEN)
# Davidson (DAVIDSON/MEN)
# Dayton (DAYTON/MEN)
# Delaware (DELAWARE/MEN)
# Delaware State (DELAWARE-STATE/MEN)
# Denver (DENVER/MEN)
# DePaul (DEPAUL/MEN)
# Detroit Mercy (DETROIT-MERCY/MEN)
# Drake (DRAKE/MEN)
# Drexel (DREXEL/MEN)
# Duke (DUKE/MEN)
# Duquesne (DUQUESNE/MEN)
# East Carolina (EAST-CAROLINA/MEN)
# East Tennessee State (EAST-TENNESSEE-STATE/MEN)
# Eastern Illinois (EASTERN-ILLINOIS/MEN)
# Eastern Kentucky (EASTERN-KENTUCKY/MEN)
# Eastern Michigan (EASTERN-MICHIGAN/MEN)
# Eastern Washington (EASTERN-WASHINGTON/MEN)
# Elon (ELON/MEN)
# Evansville (EVANSVILLE/MEN)
# Fairfield (FAIRFIELD/MEN)
# Fairleigh Dickinson (FAIRLEIGH-DICKINSON/MEN)
# Florida (FLORIDA/MEN)
# Florida A&M (FLORIDA-AM/MEN)
# Florida Atlantic (FLORIDA-ATLANTIC/MEN)
# Florida Gulf Coast (FLORIDA-GULF-COAST/MEN)
# Florida International (FLORIDA-INTERNATIONAL/MEN)
# Florida State (FLORIDA-STATE/MEN)
# Fordham (FORDHAM/MEN)
# Fresno State (FRESNO-STATE/MEN)
# Furman (FURMAN/MEN)
# Gardner-Webb (GARDNER-WEBB/MEN)
# George Mason (GEORGE-MASON/MEN)
# George Washington (GEORGE-WASHINGTON/MEN)
# Georgetown (GEORGETOWN/MEN)
# Georgia (GEORGIA/MEN)
# Georgia Southern (GEORGIA-SOUTHERN/MEN)
# Georgia State (GEORGIA-STATE/MEN)
# Georgia Tech (GEORGIA-TECH/MEN)
# Gonzaga (GONZAGA/MEN)
# Grambling (GRAMBLING/MEN)
# Grand Canyon (GRAND-CANYON/MEN)
# Green Bay (GREEN-BAY/MEN)
# Hampton (HAMPTON/MEN)
# Hartford (HARTFORD/MEN)
# Harvard (HARVARD/MEN)
# Hawaii (HAWAII/MEN)
# High Point (HIGH-POINT/MEN)
# Hofstra (HOFSTRA/MEN)
# Holy Cross (HOLY-CROSS/MEN)
# Houston (HOUSTON/MEN)
# Houston Christian (HOUSTON-BAPTIST/MEN)
# Howard (HOWARD/MEN)
# Idaho (IDAHO/MEN)
# Idaho State (IDAHO-STATE/MEN)
# Illinois (ILLINOIS/MEN)
# Illinois State (ILLINOIS-STATE/MEN)
# Illinois-Chicago (ILLINOIS-CHICAGO/MEN)
# Incarnate Word (INCARNATE-WORD/MEN)
# Indiana (INDIANA/MEN)
# Indiana State (INDIANA-STATE/MEN)
# Iona (IONA/MEN)
# Iowa (IOWA/MEN)
# Iowa State (IOWA-STATE/MEN)
# IUPUI (IUPUI/MEN)
# Jackson State (JACKSON-STATE/MEN)
# Jacksonville (JACKSONVILLE/MEN)
# Jacksonville State (JACKSONVILLE-STATE/MEN)
# James Madison (JAMES-MADISON/MEN)
# Kansas (KANSAS/MEN)
# Kansas City (MISSOURI-KANSAS-CITY/MEN)
# Kansas State (KANSAS-STATE/MEN)
# Kennesaw State (KENNESAW-STATE/MEN)
# Kent State (KENT-STATE/MEN)
# Kentucky (KENTUCKY/MEN)
# La Salle (LA-SALLE/MEN)
# Lafayette (LAFAYETTE/MEN)
# Lamar (LAMAR/MEN)
# Lehigh (LEHIGH/MEN)
# Liberty (LIBERTY/MEN)
# Lindenwood (LINDENWOOD/MEN)
# Lipscomb (LIPSCOMB/MEN)
# Little Rock (ARKANSAS-LITTLE-ROCK/MEN)
# Long Beach State (LONG-BEACH-STATE/MEN)
# Long Island University (LONG-ISLAND-UNIVERSITY/MEN)
# Longwood (LONGWOOD/MEN)
# Louisiana (LOUISIANA-LAFAYETTE/MEN)
# Louisiana State (LOUISIANA-STATE/MEN)
# Louisiana Tech (LOUISIANA-TECH/MEN)
# Louisiana-Monroe (LOUISIANA-MONROE/MEN)
# Louisville (LOUISVILLE/MEN)
# Loyola (IL) (LOYOLA-IL/MEN)
# Loyola (MD) (LOYOLA-MD/MEN)
# Loyola Marymount (LOYOLA-MARYMOUNT/MEN)
# Maine (MAINE/MEN)
# Manhattan (MANHATTAN/MEN)
# Marist (MARIST/MEN)
# Marquette (MARQUETTE/MEN)
# Marshall (MARSHALL/MEN)
# Maryland (MARYLAND/MEN)
# Maryland-Baltimore County (MARYLAND-BALTIMORE-COUNTY/MEN)
# Maryland-Eastern Shore (MARYLAND-EASTERN-SHORE/MEN)
# Massachusetts (MASSACHUSETTS/MEN)
# Massachusetts-Lowell (MASSACHUSETTS-LOWELL/MEN)
# McNeese State (MCNEESE-STATE/MEN)
# Memphis (MEMPHIS/MEN)
# Mercer (MERCER/MEN)
# Merrimack (MERRIMACK/MEN)
# Miami (FL) (MIAMI-FL/MEN)
# Miami (OH) (MIAMI-OH/MEN)
# Michigan (MICHIGAN/MEN)
# Michigan State (MICHIGAN-STATE/MEN)
# Middle Tennessee (MIDDLE-TENNESSEE/MEN)
# Milwaukee (MILWAUKEE/MEN)
# Minnesota (MINNESOTA/MEN)
# Mississippi (MISSISSIPPI/MEN)
# Mississippi State (MISSISSIPPI-STATE/MEN)
# Mississippi Valley State (MISSISSIPPI-VALLEY-STATE/MEN)
# Missouri (MISSOURI/MEN)
# Missouri State (MISSOURI-STATE/MEN)
# Monmouth (MONMOUTH/MEN)
# Montana (MONTANA/MEN)
# Montana State (MONTANA-STATE/MEN)
# Morehead State (MOREHEAD-STATE/MEN)
# Morgan State (MORGAN-STATE/MEN)
# Mount St. Mary's (MOUNT-ST-MARYS/MEN)
# Murray State (MURRAY-STATE/MEN)
# Navy (NAVY/MEN)
# NC State (NORTH-CAROLINA-STATE/MEN)
# Nebraska (NEBRASKA/MEN)
# Nevada (NEVADA/MEN)
# Nevada-Las Vegas (NEVADA-LAS-VEGAS/MEN)
# New Hampshire (NEW-HAMPSHIRE/MEN)
# New Mexico (NEW-MEXICO/MEN)
# New Mexico State (NEW-MEXICO-STATE/MEN)
# New Orleans (NEW-ORLEANS/MEN)
# Niagara (NIAGARA/MEN)
# Nicholls State (NICHOLLS-STATE/MEN)
# NJIT (NJIT/MEN)
# Norfolk State (NORFOLK-STATE/MEN)
# North Alabama (NORTH-ALABAMA/MEN)
# North Carolina (NORTH-CAROLINA/MEN)
# North Carolina A&T (NORTH-CAROLINA-AT/MEN)
# North Carolina Central (NORTH-CAROLINA-CENTRAL/MEN)
# North Dakota (NORTH-DAKOTA/MEN)
# North Dakota State (NORTH-DAKOTA-STATE/MEN)
# North Florida (NORTH-FLORIDA/MEN)
# North Texas (NORTH-TEXAS/MEN)
# Northeastern (NORTHEASTERN/MEN)
# Northern Arizona (NORTHERN-ARIZONA/MEN)
# Northern Colorado (NORTHERN-COLORADO/MEN)
# Northern Illinois (NORTHERN-ILLINOIS/MEN)
# Northern Iowa (NORTHERN-IOWA/MEN)
# Northern Kentucky (NORTHERN-KENTUCKY/MEN)
# Northwestern (NORTHWESTERN/MEN)
# Northwestern State (NORTHWESTERN-STATE/MEN)
# Notre Dame (NOTRE-DAME/MEN)
# Oakland (OAKLAND/MEN)
# Ohio (OHIO/MEN)
# Ohio State (OHIO-STATE/MEN)
# Oklahoma (OKLAHOMA/MEN)
# Oklahoma State (OKLAHOMA-STATE/MEN)
# Old Dominion (OLD-DOMINION/MEN)
# Omaha (NEBRASKA-OMAHA/MEN)
# Oral Roberts (ORAL-ROBERTS/MEN)
# Oregon (OREGON/MEN)
# Oregon State (OREGON-STATE/MEN)
# Pacific (PACIFIC/MEN)
# Penn State (PENN-STATE/MEN)
# Pennsylvania (PENNSYLVANIA/MEN)
# Pepperdine (PEPPERDINE/MEN)
# Pittsburgh (PITTSBURGH/MEN)
# Portland (PORTLAND/MEN)
# Portland State (PORTLAND-STATE/MEN)
# Prairie View (PRAIRIE-VIEW/MEN)
# Presbyterian (PRESBYTERIAN/MEN)
# Princeton (PRINCETON/MEN)
# Providence (PROVIDENCE/MEN)
# Purdue (PURDUE/MEN)
# Purdue Fort Wayne (IPFW/MEN)
# Queens (NC) (QUEENS-NC/MEN)
# Quinnipiac (QUINNIPIAC/MEN)
# Radford (RADFORD/MEN)
# Rhode Island (RHODE-ISLAND/MEN)
# Rice (RICE/MEN)
# Richmond (RICHMOND/MEN)
# Rider (RIDER/MEN)
# Robert Morris (ROBERT-MORRIS/MEN)
# Rutgers (RUTGERS/MEN)
# Sacramento State (SACRAMENTO-STATE/MEN)
# Sacred Heart (SACRED-HEART/MEN)
# Saint Francis (PA) (SAINT-FRANCIS-PA/MEN)
# Saint Joseph's (SAINT-JOSEPHS/MEN)
# Saint Louis (SAINT-LOUIS/MEN)
# Saint Mary's (CA) (SAINT-MARYS-CA/MEN)
# Saint Peter's (SAINT-PETERS/MEN)
# Sam Houston (SAM-HOUSTON-STATE/MEN)
# Samford (SAMFORD/MEN)
# San Diego (SAN-DIEGO/MEN)
# San Diego State (SAN-DIEGO-STATE/MEN)
# San Francisco (SAN-FRANCISCO/MEN)
# San Jose State (SAN-JOSE-STATE/MEN)
# Santa Clara (SANTA-CLARA/MEN)
# Seattle (SEATTLE/MEN)
# Seton Hall (SETON-HALL/MEN)
# Siena (SIENA/MEN)
# South Alabama (SOUTH-ALABAMA/MEN)
# South Carolina (SOUTH-CAROLINA/MEN)
# South Carolina State (SOUTH-CAROLINA-STATE/MEN)
# South Carolina Upstate (SOUTH-CAROLINA-UPSTATE/MEN)
# South Dakota (SOUTH-DAKOTA/MEN)
# South Dakota State (SOUTH-DAKOTA-STATE/MEN)
# South Florida (SOUTH-FLORIDA/MEN)
# Southeast Missouri State (SOUTHEAST-MISSOURI-STATE/MEN)
# Southeastern Louisiana (SOUTHEASTERN-LOUISIANA/MEN)
# Southern (SOUTHERN/MEN)
# Southern California (SOUTHERN-CALIFORNIA/MEN)
# Southern Illinois (SOUTHERN-ILLINOIS/MEN)
# SIU Edwardsville (SOUTHERN-ILLINOIS-EDWARDSVILLE/MEN)
# Southern Indiana (SOUTHERN-INDIANA/MEN)
# Southern Methodist (SOUTHERN-METHODIST/MEN)
# Southern Mississippi (SOUTHERN-MISSISSIPPI/MEN)
# Southern Utah (SOUTHERN-UTAH/MEN)
# St. Bonaventure (ST-BONAVENTURE/MEN)
# St. Francis (NY) (ST-FRANCIS-NY/MEN)
# St. John's (NY) (ST-JOHNS-NY/MEN)
# St. Thomas (ST-THOMAS-MN/MEN)
# Stanford (STANFORD/MEN)
# Stephen F. Austin (STEPHEN-F-AUSTIN/MEN)
# Stetson (STETSON/MEN)
# Stonehill (STONEHILL/MEN)
# Stony Brook (STONY-BROOK/MEN)
# Syracuse (SYRACUSE/MEN)
# Tarleton State (TARLETON-STATE/MEN)
# TCU (TEXAS-CHRISTIAN/MEN)
# Temple (TEMPLE/MEN)
# Tennessee (TENNESSEE/MEN)
# Tennessee State (TENNESSEE-STATE/MEN)
# Tennessee Tech (TENNESSEE-TECH/MEN)
# Tennessee-Martin (TENNESSEE-MARTIN/MEN)
# Texas (TEXAS/MEN)
# Texas A&M (TEXAS-AM/MEN)
# Texas A&M-Commerce (TEXAS-AM-COMMERCE/MEN)
# Texas A&M-Corpus Christi (TEXAS-AM-CORPUS-CHRISTI/MEN)
# Texas Southern (TEXAS-SOUTHERN/MEN)
# Texas State (TEXAS-STATE/MEN)
# Texas Tech (TEXAS-TECH/MEN)
# Texas-Rio Grande Valley (TEXAS-PAN-AMERICAN/MEN)
# The Citadel (CITADEL/MEN)
# Toledo (TOLEDO/MEN)
# Towson (TOWSON/MEN)
# Troy (TROY/MEN)
# Tulane (TULANE/MEN)
# Tulsa (TULSA/MEN)
# UAB (ALABAMA-BIRMINGHAM/MEN)
# UC Davis (CALIFORNIA-DAVIS/MEN)
# UC Irvine (CALIFORNIA-IRVINE/MEN)
# UC Riverside (CALIFORNIA-RIVERSIDE/MEN)
# UC San Diego (CALIFORNIA-SAN-DIEGO/MEN)
# UC Santa Barbara (CALIFORNIA-SANTA-BARBARA/MEN)
# UCLA (UCLA/MEN)
# UNC Asheville (NORTH-CAROLINA-ASHEVILLE/MEN)
# UNC Greensboro (NORTH-CAROLINA-GREENSBORO/MEN)
# UNC Wilmington (NORTH-CAROLINA-WILMINGTON/MEN)
# UT Arlington (TEXAS-ARLINGTON/MEN)
# Utah (UTAH/MEN)
# Utah State (UTAH-STATE/MEN)
# Utah Tech (DIXIE-STATE/MEN)
# Utah Valley (UTAH-VALLEY/MEN)
# UTEP (TEXAS-EL-PASO/MEN)
# UTSA (TEXAS-SAN-ANTONIO/MEN)
# Valparaiso (VALPARAISO/MEN)
# Vanderbilt (VANDERBILT/MEN)
# Vermont (VERMONT/MEN)
# Villanova (VILLANOVA/MEN)
# Virginia (VIRGINIA/MEN)
# Virginia Commonwealth (VIRGINIA-COMMONWEALTH/MEN)
# VMI (VIRGINIA-MILITARY-INSTITUTE/MEN)
# Virginia Tech (VIRGINIA-TECH/MEN)
# Wagner (WAGNER/MEN)
# Wake Forest (WAKE-FOREST/MEN)
# Washington (WASHINGTON/MEN)
# Washington State (WASHINGTON-STATE/MEN)
# Weber State (WEBER-STATE/MEN)
# West Virginia (WEST-VIRGINIA/MEN)
# Western Carolina (WESTERN-CAROLINA/MEN)
# Western Illinois (WESTERN-ILLINOIS/MEN)
# Western Kentucky (WESTERN-KENTUCKY/MEN)
# Western Michigan (WESTERN-MICHIGAN/MEN)
# Wichita State (WICHITA-STATE/MEN)
# William & Mary (WILLIAM-MARY/MEN)
# Winthrop (WINTHROP/MEN)
# Wisconsin (WISCONSIN/MEN)
# Wofford (WOFFORD/MEN)
# Wright State (WRIGHT-STATE/MEN)
# Wyoming (WYOMING/MEN)
# Xavier (XAVIER/MEN)
# Yale (YALE/MEN)
# Youngstown State (YOUNGSTOWN-STATE/MEN)

# %% [markdown]
# # Get the games schedule for today

# %%
games_today = Boxscores(datetime.today())

# %%
games_today.games
# Out:
# NCAAB games for 12-11-2023
